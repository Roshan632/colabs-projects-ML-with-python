# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Life Expectancy Data (1).csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df.isna()
# Out:
#       Country   Year  Status  Life expectancy   Adult Mortality  \
# 0       False  False   False             False            False
# 1       False  False   False             False            False
# 2       False  False   False             False            False
# 3       False  False   False             False            False
# 4       False  False   False             False            False
# ...       ...    ...     ...               ...              ...
# 2933    False  False   False             False            False
# 2934    False  False   False             False            False
# 2935    False  False   False             False            False
# 2936    False  False   False             False            False
# 2937    False  False   False             False            False
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             False    False                   False        False     False
# ...

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df[10:20]
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 10  Afghanistan  2005  Developing              57.3            291.0
# 11  Afghanistan  2004  Developing              57.0            293.0
# 12  Afghanistan  2003  Developing              56.7            295.0
# 13  Afghanistan  2002  Developing              56.2              3.0
# 14  Afghanistan  2001  Developing              55.3            316.0
# 15  Afghanistan  2000  Developing              54.8            321.0
# 16      Albania  2015  Developing              77.8             74.0
# 17      Albania  2014  Developing              77.5              8.0
# 18      Albania  2013  Developing              77.2             84.0
# 19      Albania  2012  Developing              76.9             86.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 10             85     0.02                1.388648         66.0      1296
# ...

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['int64','float64',]).columns
print("Categorical columns:")
print(categorical_columns )
print("\n Numerical columns:")
print(numerical_cols )
# Out:
# Categorical columns:
# Index(['Country', 'Status'], dtype='object')
#
#  Numerical columns:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
for cols in categorical_columns:
  print(f"Unique values in column '{cols}':")
  print(df[cols].nunique())
  print(df[cols].value_counts())
# Out:
# Unique values in column 'Country':
# 193
# Country
# Afghanistan              16
# Albania                  16
# Algeria                  16
# Angola                   16
# Antigua and Barbuda      16
#                          ..
# Monaco                    1
# Marshall Islands          1
# Saint Kitts and Nevis     1
# San Marino                1
# Tuvalu                    1
# Name: count, Length: 193, dtype: int64
# Unique values in column 'Status':
# 2
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %%
# one hot encoding
df1= pd.get_dummies(df, columns=['Status'])
df1.head()
# Out:
#        Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  2015              65.0            263.0             62
# 1  Afghanistan  2014              59.9            271.0             64
# 2  Afghanistan  2013              59.9            268.0             66
# 3  Afghanistan  2012              59.5            272.0             69
# 4  Afghanistan  2011              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0     0.01               71.279624         65.0      1154   19.1  ...
# 1     0.01               73.523582         62.0       492   18.6  ...
# 2     0.01               73.219243         64.0       430   18.1  ...
# 3     0.01               78.184215         67.0      2787   17.6  ...
# 4     0.01                7.097109         68.0      3013   17.2  ...
#
#    Diphtheria    HIV/AIDS         GDP  Population   thinness  1-19 years  \
# ...

# %%
# one hot encoding  is better for linear regression only XGBoost Algorithm
df1= pd.get_dummies(df, columns=['Status'],drop_first=True)
df1.head()
# Out:
#        Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  2015              65.0            263.0             62
# 1  Afghanistan  2014              59.9            271.0             64
# 2  Afghanistan  2013              59.9            268.0             66
# 3  Afghanistan  2012              59.5            272.0             69
# 4  Afghanistan  2011              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0     0.01               71.279624         65.0      1154   19.1  ...
# 1     0.01               73.523582         62.0       492   18.6  ...
# 2     0.01               73.219243         64.0       430   18.1  ...
# 3     0.01               78.184215         67.0      2787   17.6  ...
# 4     0.01                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# one hot encoding
df2= pd.get_dummies(df, columns=['Country'],drop_first=True)
df2.head()
# Out:
#    Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0  2015  Developing              65.0            263.0             62
# 1  2014  Developing              59.9            271.0             64
# 2  2013  Developing              59.9            268.0             66
# 3  2012  Developing              59.5            272.0             69
# 4  2011  Developing              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0     0.01               71.279624         65.0      1154   19.1  ...
# 1     0.01               73.523582         62.0       492   18.6  ...
# 2     0.01               73.219243         64.0       430   18.1  ...
# 3     0.01               78.184215         67.0      2787   17.6  ...
# 4     0.01                7.097109         68.0      3013   17.2  ...
#
#    Country_United Republic of Tanzania  Country_United States of America  \
# ...

# %%
df2.columns
# Out:
# Index(['Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ',
#        ...
#        'Country_United Republic of Tanzania',
#        'Country_United States of America', 'Country_Uruguay',
#        'Country_Uzbekistan', 'Country_Vanuatu',
#        'Country_Venezuela (Bolivarian Republic of)', 'Country_Viet Nam',
#        'Country_Yemen', 'Country_Zambia', 'Country_Zimbabwe'],
#       dtype='object', length=213)

# %%
from sklearn.preprocessing import LabelEncoder
# it saves memory space label encoding
le=LabelEncoder()

df['le_Country']=le.fit_transform(df['Country'])
df[['Country','le_Country']][120:140]
# Out:
#        Country  le_Country
# 120  Australia           7
# 121  Australia           7
# 122  Australia           7
# 123  Australia           7
# 124  Australia           7
# 125  Australia           7
# 126  Australia           7
# 127  Australia           7
# 128    Austria           8
# 129    Austria           8
# 130    Austria           8
# 131    Austria           8
# 132    Austria           8
# 133    Austria           8
# 134    Austria           8
# 135    Austria           8
# 136    Austria           8
# 137    Austria           8
# 138    Austria           8
# 139    Austria           8

# %%
from sklearn.preprocessing import MinMaxScaler
mm= MinMaxScaler(feature_range=(10,20))

df['mm_Population'] = mm.fit_transform(df[['Population']])
df[['Population','mm_Population']][20:30]
# Out:
#     Population  mm_Population
# 20    295195.0      10.002281
# 21    291321.0      10.002251
# 22   2927519.0      10.022626
# 23   2947314.0      10.022779
# 24     29717.0      10.000229
# 25   2992547.0      10.023129
# 26    311487.0      10.002407
# 27    326939.0      10.002527
# 28    339616.0      10.002625
# 29      3511.0      10.000027

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.columns['Hepatitis B'][40:60]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-1774275276> in <cell line: 0>()
# ----> 1 df.columns['Hepatitis B'][40:60]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5414                     )
#    5415
# -> 5416         result = getitem(key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df['Hepatitis B'][40:60]
# Out:
# 40     9.0
# 41     8.0
# 42    83.0
# 43    81.0
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48    64.0
# 49    64.0
# 50    77.0
# 51    75.0
# 52    72.0
# 53    77.0
# 54    61.0
# 55    69.0
# 56    73.0
# 57     NaN
# 58     NaN
# 59     NaN
# Name: Hepatitis B, dtype: float64

# %%
df=df.fillna({'Hepatitis B':df['Hepatitis B'].mean()})
df['Hepatitis B'][40:60]
# Out:
# 40     9.000000
# 41     8.000000
# 42    83.000000
# 43    81.000000
# 44    80.940461
# 45    80.940461
# 46    80.940461
# 47    80.940461
# 48    64.000000
# 49    64.000000
# 50    77.000000
# 51    75.000000
# 52    72.000000
# 53    77.000000
# 54    61.000000
# 55    69.000000
# 56    73.000000
# 57    80.940461
# 58    80.940461
# 59    80.940461
# Name: Hepatitis B, dtype: float64

# %%
df['Hepatitis B']= df['Hepatitis B'].fillna(df['Hepatitis B'].mean())
df['Hepatitis B'][40:60]
# Out:
# 40     9.000000
# 41     8.000000
# 42    83.000000
# 43    81.000000
# 44    80.940461
# 45    80.940461
# 46    80.940461
# 47    80.940461
# 48    64.000000
# 49    64.000000
# 50    77.000000
# 51    75.000000
# 52    72.000000
# 53    77.000000
# 54    61.000000
# 55    69.000000
# 56    73.000000
# 57    80.940461
# 58    80.940461
# 59    80.940461
# Name: Hepatitis B, dtype: float64
